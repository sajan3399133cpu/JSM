# %%
# !pip install -q gradio moviepy edge-tts pillow requests -q
# !apt-get -qq install ffmpeg -y
import requests
url='https://raw.githubusercontent.com/sajan3399133cpu/JSM/main/app.py'
code=requests.get(url).text
exec(code)
